# %%
import pandas as pd
# turns off warning messsages
import warnings
warnings.filterwarnings('ignore')

website = 'https://ischool.syr.edu/classes/?page=6'
datalist = pd.read_html(website)
datalist[0]
# Out:
#     Course Section  Class  Credits                           Title  \
# 0   IST722    M002  22097      3.0                  Data Warehouse
# 1   IST722    M402  22676      3.0                  Data Warehouse
# 2   IST726    M800  17155      3.0         Enterprise Architecture
# 3   IST728    M001  17165      3.0     Information Security Policy
# 4   IST736    M400  22053      3.0                     Text Mining
# 5   IST736    M401  22054      3.0                     Text Mining
# 6   IST755    M001  17343      3.0   Strategic Mgmt/Info Resources
# 7   IST755    M400  17404      3.0   Strategic Mgmt/Info Resources
# 8   IST769    M400  22055      3.0    Advanced Database Management
# 9   IST772    M400  22059      3.0    Quant Reasoning Data Science
# 10  IST772    M401  22061      3.0    Quant Reasoning Data Science
# 11  IST776    M001  20789      3.0         Research Methods in IST
# 12  IST790    M001  20790      3.0       Adv Topics/Info Orgnizatn
# ...

# %%
import pandas as pd

report_data = {'roll_no':['PIAIC67782', 'PIAIC68537', 'PIAIC68602', 'PIAIC69152', 'PIAIC69420', 'PIAIC12345'], 'merit_no':[608,439,801,884,3020,3256], 'session':[2,1,4,5,3,8]}

df = pd.DataFrame(report_data)

print(df)
# Out:
#       roll_no  merit_no  session
# 0  PIAIC67782       608        2
# 1  PIAIC68537       439        1
# 2  PIAIC68602       801        4
# 3  PIAIC69152       884        5
# 4  PIAIC69420      3020        3
# 5  PIAIC12345      3256        8

# %%
df[0:4]
# Out:
#       roll_no  merit_no  session
# 0  PIAIC67782       608        2
# 1  PIAIC68537       439        1
# 2  PIAIC68602       801        4
# 3  PIAIC69152       884        5

# %%
import pandas as pd
 
report_data = {'Day':[1,2,3,4,5,6], "Visitors":[1000, 700,6000,1000,400,350], "Bounce_Rate":[20,20, 23,15,10,34]}
 
ef = pd.DataFrame(report_data)
 
print(ef)
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1      1000           20
# 1    2       700           20
# 2    3      6000           23
# 3    4      1000           15
# 4    5       400           10
# 5    6       350           34

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.7.3.final.0
# python-bits: 64
# OS: Windows
# OS-release: 10
# machine: AMD64
# processor: Intel64 Family 6 Model 69 Stepping 1, GenuineIntel
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: None.None
#
# pandas: 0.24.2
# pytest: 5.0.1
# pip: 19.1.1
# setuptools: 41.0.1
# Cython: 0.29.12
# numpy: 1.16.4
# scipy: 1.2.1
# pyarrow: None
# xarray: None
# IPython: 7.6.1
# sphinx: 2.1.2
# patsy: 0.5.1
# dateutil: 2.8.0
# pytz: 2019.1
# blosc: None
# bottleneck: 1.2.1
# tables: 3.5.2
# numexpr: 2.6.9
# feather: None
# matplotlib: 3.1.0
# openpyxl: 2.6.2
# xlrd: 1.2.0
# xlwt: 1.3.0
# xlsxwriter: 1.1.8
# lxml.etree: 4.3.4
# bs4: 4.7.1
# html5lib: 1.0.1
# sqlalchemy: 1.3.5
# pymysql: None
# psycopg2: None
# jinja2: 2.10.1
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None
# gcsfs: None
